# %%
#import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
# Load the dataset
df = pd.read_csv('stock_prices.xls')

# %%
data = df['Close'].values.reshape(-1, 1)

# %%
# Normalize the data
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data)

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# %%
sequence_length = 20
X, y = create_sequences(data_normalized, sequence_length)

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
model = Sequential([
    SimpleRNN(units=50, input_shape=(X.shape[1], X.shape[2]), activation='relu'),
    Dense(units=1)
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 13s 242ms/step - loss: 0.1825 - val_loss: 0.0087
# Epoch 2/50
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0108 - val_loss: 0.0131
# Epoch 3/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0043 - val_loss: 0.0024
# Epoch 4/50
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 5/50
# 14/14 [==============================] - 1s 41ms/step - loss: 5.8037e-04 - val_loss: 0.0027
# Epoch 6/50
# 14/14 [==============================] - 0s 32ms/step - loss: 5.4454e-04 - val_loss: 0.0022
# Epoch 7/50
# 14/14 [==============================] - 0s 25ms/step - loss: 5.1076e-04 - val_loss: 0.0021
# Epoch 8/50
# 14/14 [==============================] - 0s 34ms/step - loss: 5.2920e-04 - val_loss: 0.0021
# Epoch 9/50
# 14/14 [==============================] - 0s 29ms/step - loss: 5.4213e-04 - val_loss: 0.0022
# Epoch 10/50
# 14/14 [==============================] - 0s 31ms/step - loss: 5.1044e-04 - val_loss: 0.0021
# Epoch 11/50
# 14/14 [==============================] - 0s 29ms/step - loss: 4.9756e-04 - val_loss: 0.0023
# Epoch 12/50
# 14/14 [==============================] - 0s 32ms/step - loss: 4.9289e-04 - val_loss: 0.0022
# Epoch 13/50
# 14/14 [==============================] - 0s 31ms/step - loss: 4.9579e-04 - val_loss: 0.0022
# Epoch 14/50
# 14/14 [==============================] - 0s 32ms/step - loss: 5.0783e-04 - val_loss: 0.0020
# Epoch 15/50
# 14/14 [==============================] - 0s 34ms/step - loss: 4.9625e-04 - val_loss: 0.0021
# Epoch 16/50
# 14/14 [==============================] - 1s 38ms/step - loss: 4.7744e-04 - val_loss: 0.0021
# Epoch 17/50
# 14/14 [==============================] - 0s 35ms/step - loss: 4.7960e-04 - val_loss: 0.0022
# Epoch 18/50
# 14/14 [==============================] - 0s 35ms/step - loss: 4.7676e-04 - val_loss: 0.0020
# Epoch 19/50
# 14/14 [==============================] - 0s 32ms/step - loss: 4.8561e-04 - val_loss: 0.0022
# Epoch 20/50
# 14/14 [==============================] - 0s 34ms/step - loss: 4.7036e-04 - val_loss: 0.0020
# Epoch 21/50
# 14/14 [==============================] - 0s 32ms/step - loss: 4.9174e-04 - val_loss: 0.0019
# Epoch 22/50
# 14/14 [==============================] - 0s 35ms/step - loss: 5.2748e-04 - val_loss: 0.0019
# Epoch 23/50
# 14/14 [==============================] - 0s 30ms/step - loss: 4.6775e-04 - val_loss: 0.0022
# Epoch 24/50
# 14/14 [==============================] - 0s 33ms/step - loss: 4.7152e-04 - val_loss: 0.0020
# Epoch 25/50
# 14/14 [==============================] - 0s 35ms/step - loss: 5.1078e-04 - val_loss: 0.0020
# Epoch 26/50
# 14/14 [==============================] - 0s 32ms/step - loss: 4.8221e-04 - val_loss: 0.0021
# Epoch 27/50
# 14/14 [==============================] - 0s 35ms/step - loss: 4.5729e-04 - val_loss: 0.0022
# Epoch 28/50
# 14/14 [==============================] - 0s 30ms/step - loss: 4.6905e-04 - val_loss: 0.0022
# Epoch 29/50
# 14/14 [==============================] - 1s 35ms/step - loss: 4.6006e-04 - val_loss: 0.0020
# Epoch 30/50
# 14/14 [==============================] - 0s 31ms/step - loss: 4.5188e-04 - val_loss: 0.0021
# Epoch 31/50
# 14/14 [==============================] - 0s 30ms/step - loss: 4.5545e-04 - val_loss: 0.0019
# Epoch 32/50
# 14/14 [==============================] - 0s 35ms/step - loss: 4.5363e-04 - val_loss: 0.0019
# Epoch 33/50
# 14/14 [==============================] - 0s 35ms/step - loss: 4.4138e-04 - val_loss: 0.0024
# Epoch 34/50
# 14/14 [==============================] - 0s 30ms/step - loss: 4.9251e-04 - val_loss: 0.0019
# Epoch 35/50
# 14/14 [==============================] - 0s 26ms/step - loss: 4.5851e-04 - val_loss: 0.0018
# Epoch 36/50
# 14/14 [==============================] - 0s 31ms/step - loss: 4.6691e-04 - val_loss: 0.0019
# Epoch 37/50
# 14/14 [==============================] - 0s 32ms/step - loss: 4.4799e-04 - val_loss: 0.0021
# Epoch 38/50
# 14/14 [==============================] - 0s 28ms/step - loss: 4.3631e-04 - val_loss: 0.0019
# Epoch 39/50
# 14/14 [==============================] - 0s 26ms/step - loss: 4.3489e-04 - val_loss: 0.0021
# Epoch 40/50
# 14/14 [==============================] - 0s 22ms/step - loss: 4.4282e-04 - val_loss: 0.0020
# Epoch 41/50
# 14/14 [==============================] - 0s 32ms/step - loss: 4.4689e-04 - val_loss: 0.0019
# Epoch 42/50
# 14/14 [==============================] - 0s 32ms/step - loss: 4.3452e-04 - val_loss: 0.0020
# Epoch 43/50
# 14/14 [==============================] - 1s 75ms/step - loss: 4.6078e-04 - val_loss: 0.0018
# Epoch 44/50
# 14/14 [==============================] - 1s 54ms/step - loss: 4.4175e-04 - val_loss: 0.0018
# Epoch 45/50
# 14/14 [==============================] - 1s 83ms/step - loss: 4.3018e-04 - val_loss: 0.0017
# Epoch 46/50
# 14/14 [==============================] - 1s 95ms/step - loss: 4.1986e-04 - val_loss: 0.0018
# Epoch 47/50
# 14/14 [==============================] - 1s 80ms/step - loss: 4.4146e-04 - val_loss: 0.0017
# Epoch 48/50
# 14/14 [==============================] - 0s 23ms/step - loss: 4.3924e-04 - val_loss: 0.0019
# Epoch 49/50
# 14/14 [==============================] - 0s 26ms/step - loss: 4.1217e-04 - val_loss: 0.0020
# Epoch 50/50
# 14/14 [==============================] - 0s 33ms/step - loss: 4.3015e-04 - val_loss: 0.0020

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
# Out:
# 16/16 [==============================] - 2s 7ms/step
# 4/4 [==============================] - 0s 10ms/step

# %%
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)

# %%
from sklearn.metrics import mean_squared_error
train_rmse = np.sqrt(mean_squared_error(scaler.inverse_transform(y_train), y_train_pred_actual))
test_rmse = np.sqrt(mean_squared_error(scaler.inverse_transform(y_test), y_test_pred_actual))

# %%
print(f'Train RMSE: {train_rmse:.4f}')
print(f'Test RMSE: {test_rmse:.4f}')
# Out:
# Train RMSE: 2.3807
# Test RMSE: 3.7988

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Train Loss: {train_loss:.4f}')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# Train Loss: 0.0006
# Test Loss: 0.0015

# %%
# Make predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform the predictions to get actual prices
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)
# Out:
# 16/16 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 8ms/step

# %%
# Plot predictions vs actual values for the test set
plt.figure(figsize=(12, 6))
plt.plot(df.index[split+sequence_length:], y_test_pred_actual, label='Predicted')
plt.plot(df.index[split+sequence_length:], scaler.inverse_transform(y_test), label='Actual')
plt.title('Google Stock Price Prediction (Test Set)')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
